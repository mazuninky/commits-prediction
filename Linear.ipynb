# %%
from pandas import Series
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot

# %%
time_series = Series.from_csv('commit_data.csv', header=0)
time_series.head()
# Out:
# Date
# 2016-10-09 09:00:00    1
# 2017-05-02 10:00:00    1
# 2017-07-25 18:00:00    1
# 2017-08-02 18:00:00    1
# 2017-08-14 11:00:00    1
# Name: Commits, dtype: int64

# %%
time_series.plot()
pyplot.show()

# %%
lr  = LinearRegression
